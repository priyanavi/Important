# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\gss\anaconda3\lib\site-packages (2.15.0)
# Requirement already satisfied: tensorflow-intel==2.15.0 in c:\users\gss\anaconda3\lib\site-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\gss\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\gss\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\gss\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\gss\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\gss\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\gss\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\gss\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in c:\users\gss\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in c:\users\gss\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.24.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\gss\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\gss\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\gss\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (4.23.4)
# Requirement already satisfied: setuptools in c:\users\gss\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\gss\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\gss\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\gss\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (4.7.1)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\gss\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\gss\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\gss\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.60.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in c:\users\gss\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.1)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in c:\users\gss\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in c:\users\gss\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\gss\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.15.0->tensorflow) (0.38.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\gss\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.25.2)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in c:\users\gss\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\gss\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\gss\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\gss\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\gss\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.2.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\gss\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\gss\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\gss\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\gss\anaconda3\lib\site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\gss\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gss\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\gss\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gss\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\gss\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\gss\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\gss\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Packages

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# %% [markdown]
# # Load the Dataset

# %%
# Load the data
df = pd.read_csv("ATM_cash_flow_data.csv")  
df.head()
# Out:
#              ATM Name Transaction Date  No Of Withdrawals  \
# 0      Big Street ATM         1/1/2011                 50
# 1      Mount Road ATM         1/1/2011                253
# 2         Airport ATM         1/1/2011                 98
# 3        KK Nagar ATM         1/1/2011                265
# 4  Christ College ATM         1/1/2011                 74
#
#    No Of XYZ Card Withdrawals  No Of Other Card Withdrawals  \
# 0                          20                            30
# 1                          67                           186
# 2                          56                            42
# 3                         159                           106
# 4                          25                            49
#
#    Total amount Withdrawn  Amount withdrawn XYZ Card  \
# 0                  123800                      41700
# 1                  767900                     270900
# 2                  503400                     347700
# 3                  945300                     532600
# 4                  287700                     148200
#
#    Amount withdrawn Other Card   Weekday Festival Religion Working Day  \
# 0                        82100  Saturday                 H           H
# 1                       497000  Saturday                 C           H
# 2                       155700  Saturday                 C           H
# 3                       412700  Saturday                 C           H
# 4                       139500  Saturday                 C           H
#
#   Holiday Sequence
# 0              HHW
# 1              HHW
# 2              HHW
# 3              HHW
# 4              HHW

# %% [markdown]
# # Preprocessing

# %%
df.isnull().sum()
# Out:
# ATM Name                        0
# Transaction Date                0
# No Of Withdrawals               0
# No Of XYZ Card Withdrawals      0
# No Of Other Card Withdrawals    0
# Total amount Withdrawn          0
# Amount withdrawn XYZ Card       0
# Amount withdrawn Other Card     0
# Weekday                         0
# Festival Religion               0
# Working Day                     0
# Holiday Sequence                0
# dtype: int64

# %%
# Convert 'Transaction Date' to datetime format
df['Transaction Date'] = pd.to_datetime(df['Transaction Date'])
df.head()
# Out:
#              ATM Name Transaction Date  No Of Withdrawals  \
# 0      Big Street ATM       2011-01-01                 50
# 1      Mount Road ATM       2011-01-01                253
# 2         Airport ATM       2011-01-01                 98
# 3        KK Nagar ATM       2011-01-01                265
# 4  Christ College ATM       2011-01-01                 74
#
#    No Of XYZ Card Withdrawals  No Of Other Card Withdrawals  \
# 0                          20                            30
# 1                          67                           186
# 2                          56                            42
# 3                         159                           106
# 4                          25                            49
#
#    Total amount Withdrawn  Amount withdrawn XYZ Card  \
# 0                  123800                      41700
# 1                  767900                     270900
# 2                  503400                     347700
# 3                  945300                     532600
# 4                  287700                     148200
#
#    Amount withdrawn Other Card   Weekday Festival Religion Working Day  \
# 0                        82100  Saturday                 H           H
# 1                       497000  Saturday                 C           H
# 2                       155700  Saturday                 C           H
# 3                       412700  Saturday                 C           H
# 4                       139500  Saturday                 C           H
#
#   Holiday Sequence
# 0              HHW
# 1              HHW
# 2              HHW
# 3              HHW
# 4              HHW

# %%
# Convert the 'Transaction Date' column to datetime format
df['Transaction Date'] = pd.to_datetime(df['Transaction Date'], format="%d-%m-%Y")

# Create new columns for Year, Month, Day, and Weekday
df['Year'] = df['Transaction Date'].dt.year
df['Month'] = df['Transaction Date'].dt.month
df['Day'] =  df['Transaction Date'].dt.day
df['Weekday'] = df['Transaction Date'].dt.dayofweek

# %%
df.head()
# Out:
#              ATM Name Transaction Date  No Of Withdrawals  \
# 0      Big Street ATM       2011-01-01                 50
# 1      Mount Road ATM       2011-01-01                253
# 2         Airport ATM       2011-01-01                 98
# 3        KK Nagar ATM       2011-01-01                265
# 4  Christ College ATM       2011-01-01                 74
#
#    No Of XYZ Card Withdrawals  No Of Other Card Withdrawals  \
# 0                          20                            30
# 1                          67                           186
# 2                          56                            42
# 3                         159                           106
# 4                          25                            49
#
#    Total amount Withdrawn  Amount withdrawn XYZ Card  \
# 0                  123800                      41700
# 1                  767900                     270900
# 2                  503400                     347700
# 3                  945300                     532600
# 4                  287700                     148200
#
#    Amount withdrawn Other Card  Weekday Festival Religion Working Day  \
# 0                        82100        5                 H           H
# 1                       497000        5                 C           H
# 2                       155700        5                 C           H
# 3                       412700        5                 C           H
# 4                       139500        5                 C           H
#
#   Holiday Sequence  Year  Month  Day
# 0              HHW  2011      1    1
# 1              HHW  2011      1    1
# 2              HHW  2011      1    1
# 3              HHW  2011      1    1
# 4              HHW  2011      1    1

# %%
# Create new columns for sin and cos waves for the month
df['Sin_Month'] = np.sin(2 * np.pi * df['Month'] / 12)
df['Cos_Month'] = np.cos(2 * np.pi * df['Month'] / 12)

df.head()
# Out:
#              ATM Name Transaction Date  No Of Withdrawals  \
# 0      Big Street ATM       2011-01-01                 50
# 1      Mount Road ATM       2011-01-01                253
# 2         Airport ATM       2011-01-01                 98
# 3        KK Nagar ATM       2011-01-01                265
# 4  Christ College ATM       2011-01-01                 74
#
#    No Of XYZ Card Withdrawals  No Of Other Card Withdrawals  \
# 0                          20                            30
# 1                          67                           186
# 2                          56                            42
# 3                         159                           106
# 4                          25                            49
#
#    Total amount Withdrawn  Amount withdrawn XYZ Card  \
# 0                  123800                      41700
# 1                  767900                     270900
# 2                  503400                     347700
# 3                  945300                     532600
# 4                  287700                     148200
#
#    Amount withdrawn Other Card  Weekday Festival Religion Working Day  \
# 0                        82100        5                 H           H
# 1                       497000        5                 C           H
# 2                       155700        5                 C           H
# 3                       412700        5                 C           H
# 4                       139500        5                 C           H
#
#   Holiday Sequence  Year  Month  Day  Sin_Month  Cos_Month
# 0              HHW  2011      1    1        0.5   0.866025
# 1              HHW  2011      1    1        0.5   0.866025
# 2              HHW  2011      1    1        0.5   0.866025
# 3              HHW  2011      1    1        0.5   0.866025
# 4              HHW  2011      1    1        0.5   0.866025

# %%
# Plot the sine and cosine waves
plt.figure(figsize=(10, 6))
plt.plot(df['Transaction Date'], df['Sin_Month'], label='Sin Wave')
plt.plot(df['Transaction Date'], df['Cos_Month'], label='Cos Wave')

plt.title('Sin and Cos Waves for the Month')
plt.xlabel('Transaction Date')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['Transaction Date'], df['Sin_Month'], label='Sin Wave', marker='o')
plt.scatter(df['Transaction Date'], df['Cos_Month'], label='Cos Wave', marker='x')

plt.title('Sin and Cos Waves for the Month')
plt.xlabel('Transaction Date')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(10, 8), sharex=True)

axes[0].plot(df['Transaction Date'], df['Sin_Month'], label='Sin Wave')
axes[0].set_ylabel('Sin Value')
axes[0].legend()

axes[1].plot(df['Transaction Date'], df['Cos_Month'], label='Cos Wave', color='orange')
axes[1].set_xlabel('Transaction Date')
axes[1].set_ylabel('Cos Value')
axes[1].legend()

plt.suptitle('Sin and Cos Waves for the Month')
plt.show()

# %%
# Assuming 'df' is your DataFrame
df.set_index('Transaction Date', inplace=True)

# %%
df.head()
# Out:
#                             ATM Name  No Of Withdrawals  \
# Transaction Date
# 2011-01-01            Big Street ATM                 50
# 2011-01-01            Mount Road ATM                253
# 2011-01-01               Airport ATM                 98
# 2011-01-01              KK Nagar ATM                265
# 2011-01-01        Christ College ATM                 74
#
#                   No Of XYZ Card Withdrawals  No Of Other Card Withdrawals  \
# Transaction Date
# 2011-01-01                                20                            30
# 2011-01-01                                67                           186
# 2011-01-01                                56                            42
# 2011-01-01                               159                           106
# 2011-01-01                                25                            49
#
#                   Total amount Withdrawn  Amount withdrawn XYZ Card  \
# Transaction Date
# 2011-01-01                        123800                      41700
# 2011-01-01                        767900                     270900
# 2011-01-01                        503400                     347700
# 2011-01-01                        945300                     532600
# 2011-01-01                        287700                     148200
#
#                   Amount withdrawn Other Card  Weekday Festival Religion  \
# Transaction Date
# 2011-01-01                              82100        5                 H
# 2011-01-01                             497000        5                 C
# 2011-01-01                             155700        5                 C
# 2011-01-01                             412700        5                 C
# 2011-01-01                             139500        5                 C
#
#                  Working Day Holiday Sequence  Year  Month  Day  Sin_Month  \
# Transaction Date
# 2011-01-01                 H              HHW  2011      1    1        0.5
# 2011-01-01                 H              HHW  2011      1    1        0.5
# 2011-01-01                 H              HHW  2011      1    1        0.5
# 2011-01-01                 H              HHW  2011      1    1        0.5
# 2011-01-01                 H              HHW  2011      1    1        0.5
#
#                   Cos_Month
# Transaction Date
# 2011-01-01         0.866025
# 2011-01-01         0.866025
# 2011-01-01         0.866025
# 2011-01-01         0.866025
# 2011-01-01         0.866025

# %%
df.count()
# Out:
# ATM Name                        11589
# No Of Withdrawals               11589
# No Of XYZ Card Withdrawals      11589
# No Of Other Card Withdrawals    11589
# Total amount Withdrawn          11589
# Amount withdrawn XYZ Card       11589
# Amount withdrawn Other Card     11589
# Weekday                         11589
# Festival Religion               11589
# Working Day                     11589
# Holiday Sequence                11589
# Year                            11589
# Month                           11589
# Day                             11589
# Sin_Month                       11589
# Cos_Month                       11589
# dtype: int64

# %%
# Assuming 'df' is your DataFrame
df.drop_duplicates(inplace=True)

# %%
df.count()
# Out:
# ATM Name                        11589
# No Of Withdrawals               11589
# No Of XYZ Card Withdrawals      11589
# No Of Other Card Withdrawals    11589
# Total amount Withdrawn          11589
# Amount withdrawn XYZ Card       11589
# Amount withdrawn Other Card     11589
# Weekday                         11589
# Festival Religion               11589
# Working Day                     11589
# Holiday Sequence                11589
# Year                            11589
# Month                           11589
# Day                             11589
# Sin_Month                       11589
# Cos_Month                       11589
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 11589 entries, 2011-01-01 to 2017-09-29
# Data columns (total 16 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ATM Name                      11589 non-null  object
#  1   No Of Withdrawals             11589 non-null  int64
#  2   No Of XYZ Card Withdrawals    11589 non-null  int64
#  3   No Of Other Card Withdrawals  11589 non-null  int64
#  4   Total amount Withdrawn        11589 non-null  int64
#  5   Amount withdrawn XYZ Card     11589 non-null  int64
#  6   Amount withdrawn Other Card   11589 non-null  int64
#  7   Weekday                       11589 non-null  int32
#  8   Festival Religion             11589 non-null  object
#  9   Working Day                   11589 non-null  object
#  10  Holiday Sequence              11589 non-null  object
#  11  Year                          11589 non-null  int32
#  12  Month                         11589 non-null  int32
#  13  Day                           11589 non-null  int32
#  14  Sin_Month                     11589 non-null  float64
#  15  Cos_Month                     11589 non-null  float64
# dtypes: float64(2), int32(4), int64(6), object(4)
# memory usage: 1.3+ MB

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder


# Specify columns containing string values that need to be encoded
columns_to_encode = ['ATM Name','Working Day', 'Festival Religion','Holiday Sequence']

# Use LabelEncoder to encode string values to numeric
label_encoder = LabelEncoder()
for column in columns_to_encode:
    df[column] = label_encoder.fit_transform(df[column])

# %%
df.head()
# Out:
#                   ATM Name  No Of Withdrawals  No Of XYZ Card Withdrawals  \
# Transaction Date
# 2011-01-01               1                 50                          20
# 2011-01-01               4                253                          67
# 2011-01-01               0                 98                          56
# 2011-01-01               3                265                         159
# 2011-01-01               2                 74                          25
#
#                   No Of Other Card Withdrawals  Total amount Withdrawn  \
# Transaction Date
# 2011-01-01                                  30                  123800
# 2011-01-01                                 186                  767900
# 2011-01-01                                  42                  503400
# 2011-01-01                                 106                  945300
# 2011-01-01                                  49                  287700
#
#                   Amount withdrawn XYZ Card  Amount withdrawn Other Card  \
# Transaction Date
# 2011-01-01                            41700                        82100
# 2011-01-01                           270900                       497000
# 2011-01-01                           347700                       155700
# 2011-01-01                           532600                       412700
# 2011-01-01                           148200                       139500
#
#                   Weekday  Festival Religion  Working Day  Holiday Sequence  \
# Transaction Date
# 2011-01-01              5                  1            0                 1
# 2011-01-01              5                  0            0                 1
# 2011-01-01              5                  0            0                 1
# 2011-01-01              5                  0            0                 1
# 2011-01-01              5                  0            0                 1
#
#                   Year  Month  Day  Sin_Month  Cos_Month
# Transaction Date
# 2011-01-01        2011      1    1        0.5   0.866025
# 2011-01-01        2011      1    1        0.5   0.866025
# 2011-01-01        2011      1    1        0.5   0.866025
# 2011-01-01        2011      1    1        0.5   0.866025
# 2011-01-01        2011      1    1        0.5   0.866025

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 11589 entries, 2011-01-01 to 2017-09-29
# Data columns (total 16 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ATM Name                      11589 non-null  int32
#  1   No Of Withdrawals             11589 non-null  int64
#  2   No Of XYZ Card Withdrawals    11589 non-null  int64
#  3   No Of Other Card Withdrawals  11589 non-null  int64
#  4   Total amount Withdrawn        11589 non-null  int64
#  5   Amount withdrawn XYZ Card     11589 non-null  int64
#  6   Amount withdrawn Other Card   11589 non-null  int64
#  7   Weekday                       11589 non-null  int32
#  8   Festival Religion             11589 non-null  int32
#  9   Working Day                   11589 non-null  int32
#  10  Holiday Sequence              11589 non-null  int32
#  11  Year                          11589 non-null  int32
#  12  Month                         11589 non-null  int32
#  13  Day                           11589 non-null  int32
#  14  Sin_Month                     11589 non-null  float64
#  15  Cos_Month                     11589 non-null  float64
# dtypes: float64(2), int32(8), int64(6)
# memory usage: 1.1 MB

# %%
df.columns
# Out:
# Index(['ATM Name', 'No Of Withdrawals', 'No Of XYZ Card Withdrawals',
#        'No Of Other Card Withdrawals', 'Total amount Withdrawn',
#        'Amount withdrawn XYZ Card', 'Amount withdrawn Other Card', 'Weekday',
#        'Festival Religion', 'Working Day', 'Holiday Sequence', 'Year', 'Month',
#        'Day', 'Sin_Month', 'Cos_Month'],
#       dtype='object')

# %%
# Remove and return the column 'Total amount Withdrawn', and then reinsert it at the last position
df['Total amount Withdrawn'] = df.pop('Total amount Withdrawn')

# %%
df.describe()
# Out:
#            ATM Name  No Of Withdrawals  No Of XYZ Card Withdrawals  \
# count  11589.000000       11589.000000                11589.000000
# mean       2.001985         123.341099                   67.567694
# std        1.401493          67.315288                   47.849517
# min        0.000000           1.000000                    0.000000
# 25%        1.000000          79.000000                   34.000000
# 50%        2.000000         115.000000                   57.000000
# 75%        3.000000         158.000000                   87.000000
# max        4.000000         491.000000                  345.000000
#
#        No Of Other Card Withdrawals  Amount withdrawn XYZ Card  \
# count                  11589.000000               1.158900e+04
# mean                      55.773406               3.345604e+05
# std                       38.506475               2.470771e+05
# min                        0.000000               0.000000e+00
# 25%                       25.000000               1.560000e+05
# 50%                       50.000000               2.816000e+05
# 75%                       78.000000               4.485000e+05
# max                      310.000000               1.907800e+06
#
#        Amount withdrawn Other Card       Weekday  Festival Religion  \
# count                 1.158900e+04  11589.000000       11589.000000
# mean                  1.877455e+05      2.989300           3.816119
# std                   1.502351e+05      1.996473           0.702893
# min                   0.000000e+00      0.000000           0.000000
# 25%                   7.910000e+04      1.000000           4.000000
# 50%                   1.586000e+05      3.000000           4.000000
# 75%                   2.560000e+05      5.000000           4.000000
# max                   1.472600e+06      6.000000           4.000000
#
#         Working Day  Holiday Sequence          Year         Month  \
# count  11589.000000      11589.000000  11589.000000  11589.000000
# mean       0.571318          3.862801   2013.760549      6.346967
# std        0.494909          2.657368      1.920326      3.375119
# min        0.000000          0.000000   2011.000000      1.000000
# 25%        0.000000          1.000000   2012.000000      3.000000
# 50%        1.000000          3.000000   2014.000000      6.000000
# 75%        1.000000          7.000000   2015.000000      9.000000
# max        1.000000          7.000000   2017.000000     12.000000
#
#                 Day     Sin_Month     Cos_Month  Total amount Withdrawn
# count  11589.000000  1.158900e+04  1.158900e+04            1.158900e+04
# mean      15.714471  5.952484e-03 -3.537544e-02            5.223059e+05
# std        8.877120  7.138987e-01  6.993912e-01            3.248167e+05
# min        1.000000 -1.000000e+00 -1.000000e+00            1.000000e+02
# 25%        8.000000 -8.660254e-01 -8.660254e-01            3.057000e+05
# 50%       16.000000  1.224647e-16 -1.836970e-16            4.700000e+05
# 75%       23.000000  8.660254e-01  5.000000e-01            6.716000e+05
# max       31.000000  1.000000e+00  1.000000e+00            2.549800e+06

# %%
X = df.drop('Total amount Withdrawn' , axis = 1) # Features are all columns except the last one
y = df["Total amount Withdrawn"]   # Target variable is the last column

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.2)
#X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, random_state=1, test_size=0.1)

# %%
X_train
# Out:
#                   ATM Name  No Of Withdrawals  No Of XYZ Card Withdrawals  \
# Transaction Date
# 2013-11-10               3                249                         190
# 2015-11-16               3                106                          65
# 2013-07-31               0                141                         107
# 2011-01-16               0                 42                          33
# 2017-10-03               1                 67                          20
# ...                    ...                ...                         ...
# 2017-06-19               4                 42                          12
# 2011-07-30               2                109                          51
# 2011-10-14               3                171                         134
# 2012-05-03               0                103                          82
# 2013-06-23               1                 98                          28
#
#                   No Of Other Card Withdrawals  Amount withdrawn XYZ Card  \
# Transaction Date
# 2013-11-10                                  59                     918200
# 2015-11-16                                  41                     366700
# 2013-07-31                                  34                     550500
# 2011-01-16                                   9                     132800
# 2017-10-03                                  47                      80300
# ...                                        ...                        ...
# 2017-06-19                                  30                      53000
# 2011-07-30                                  58                     199800
# 2011-10-14                                  37                     545000
# 2012-05-03                                  21                     482000
# 2013-06-23                                  70                      49600
#
#                   Amount withdrawn Other Card  Weekday  Festival Religion  \
# Transaction Date
# 2013-11-10                             283000        6                  4
# 2015-11-16                             229600        0                  4
# 2013-07-31                              72100        2                  4
# 2011-01-16                              21300        6                  1
# 2017-10-03                             127100        1                  4
# ...                                       ...      ...                ...
# 2017-06-19                              27700        0                  4
# 2011-07-30                             225100        5                  4
# 2011-10-14                             167700        4                  4
# 2012-05-03                              70300        3                  4
# 2013-06-23                             130200        6                  4
#
#                   Working Day  Holiday Sequence  Year  Month  Day  \
# Transaction Date
# 2013-11-10                  1                 6  2013     11   10
# 2015-11-16                  1                 3  2015     11   16
# 2013-07-31                  1                 7  2013      7   31
# 2011-01-16                  0                 0  2011      1   16
# 2017-10-03                  1                 6  2017     10    3
# ...                       ...               ...   ...    ...  ...
# 2017-06-19                  1                 3  2017      6   19
# 2011-07-30                  0                 1  2011      7   30
# 2011-10-14                  1                 6  2011     10   14
# 2012-05-03                  0                 1  2012      5    3
# 2013-06-23                  0                 1  2013      6   23
#
#                      Sin_Month  Cos_Month
# Transaction Date
# 2013-11-10       -5.000000e-01   0.866025
# 2015-11-16       -5.000000e-01   0.866025
# 2013-07-31       -5.000000e-01  -0.866025
# 2011-01-16        5.000000e-01   0.866025
# 2017-10-03       -8.660254e-01   0.500000
# ...                        ...        ...
# 2017-06-19        1.224647e-16  -1.000000
# 2011-07-30       -5.000000e-01  -0.866025
# 2011-10-14       -8.660254e-01   0.500000
# 2012-05-03        5.000000e-01  -0.866025
# 2013-06-23        1.224647e-16  -1.000000
#
# [9271 rows x 15 columns]

# %%
y_train
# Out:
# Transaction Date
# 2013-11-10    1201200
# 2015-11-16     596300
# 2013-07-31     622600
# 2011-01-16     154100
# 2017-10-03     207400
#                ...
# 2017-06-19      80700
# 2011-07-30     424900
# 2011-10-14     712700
# 2012-05-03     552300
# 2013-06-23     179800
# Name: Total amount Withdrawn, Length: 9271, dtype: int64

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=2)
X_train_poly = poly.fit_transform(X_train)
X_test_poly = poly.transform(X_test)

# %%
from sklearn.preprocessing import StandardScaler
std = StandardScaler()
X_train_scale= std.fit_transform(X_train_poly)
#X_val_scale= std.fit_transform(X_val)
X_test_scale= std.transform(X_test_poly)

# %%
# Assuming y_train, y_val, and y_test are pandas Series objects
# Convert them to numpy arrays
y_train_np = y_train.to_numpy().reshape(-1, 1)
#y_val_np = y_val.to_numpy().reshape(-1, 1)
y_test_np = y_test.to_numpy().reshape(-1, 1)


y_train_scale= std.fit_transform(y_train_np)
#y_val_scale= std.fit_transform(y_val_np)
y_test_scale= std.transform(y_test_np)

# %%
y_train_scale
# Out:
# array([[ 2.10944122],
#        [ 0.23739957],
#        [ 0.31879269],
#        ...,
#        [ 0.59763374],
#        [ 0.10122858],
#        [-1.05158265]])

# %% [markdown]
# # Import the Model

# %%
from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
import xgboost as xgb
base_estimator = LinearRegression()
# Instantiate and train the AdaBoost classifier
#base_estimator = DecisionTreeRegressor(max_depth=100 ,criterion='squared_error', splitter='best',min_samples_split=3)
    #max_depth=None,
    #min_samples_split=2,
    #min_samples_leaf=1,
    #min_weight_fraction_leaf=0.0,
    #max_features=None,
    #random_state=None,
    #max_leaf_nodes=None,
    #min_impurity_decrease=0.0,
    #ccp_alpha=0.0)
#adaboost = xgb.XGBRegressor(objective='reg:squarederror', random_state=42,n_estimators=1000,learning_rate=0.2,booster='gblinear')
#adaboost = AdaBoostRegressor(base_estimator=base_estimator, n_estimators=100, learning_rate=0.1)
adaboost = AdaBoostRegressor(base_estimator=base_estimator, n_estimators=1000, learning_rate=0.1)

# %% [markdown]
# # TRAIN THE DATASET

# %%
adaboost.fit(X_train_scale, y_train_scale)
predictions = adaboost.predict(X_train_scale)
print(predictions)
# Out:
# C:\Users\gss\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\gss\anaconda3\Lib\site-packages\sklearn\ensemble\_base.py:156: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# [ 2.10944122  0.23739957  0.31879269 ...  0.59763374  0.10122858
#  -1.05158265]

# %%
# Plot actual vs predicted values
plt.figure(figsize=(10, 6))
plt.scatter(y_train_scale, predictions, color='blue')
plt.plot([min(y_train_scale), max(y_train_scale)], [min(y_train_scale), max(y_train_scale)], linestyle='--', color='red')
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Actual vs Predicted Values on Training Data")
plt.show()

# %% [markdown]
# # Error rate of Trained data

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
# Mean Squared Error (MSE)
mse = mean_squared_error(y_train_scale, predictions)
print("Mean Squared Error (MSE):", mse)

# Root Mean Squared Error (RMSE)
rmse = mean_squared_error(y_train_scale, predictions, squared=False)
print("Root Mean Squared Error (RMSE):", rmse)

# Mean Absolute Error (MAE)
mae = mean_absolute_error(y_train_scale, predictions)
print("Mean Absolute Error (MAE):", mae)

# Coefficient of Determination (R^2 Score)
r2 = r2_score(y_train_scale, predictions)
print("Coefficient of Determination (R^2 Score):", r2)

# # Mean Squared Logarithmic Error (MSLE)
# msle = mean_squared_log_error(y_train, predictions)
# print("Mean Squared Logarithmic Error (MSLE):", msle)
# Out:
# Mean Squared Error (MSE): 1.0658654083639126e-31
# Root Mean Squared Error (RMSE): 3.264759422015522e-16
# Mean Absolute Error (MAE): 2.507087959169551e-16
# Coefficient of Determination (R^2 Score): 1.0

# %% [markdown]
# # Convert Original Data

# %%
# from sklearn.preprocessing import StandardScaler
# Create a StandardScaler object
# Assuming 'predictions' contains the scaled predictions
predictions=predictions.reshape(-1,1)
# Inverse transform scaled predictions back to original scale
y_pred_rescaled = std.inverse_transform(predictions)
# Print the rescaled predictions
print(y_pred_rescaled)
# Out:
# [[1201200.]
#  [ 596300.]
#  [ 622600.]
#  ...
#  [ 712700.]
#  [ 552300.]
#  [ 179800.]]

# %%
# Concatenate the two DataFrames side by side
original_train_df = pd.concat([X_train, y_train], axis=1)
# Display the concatenated DataFrame
original_train_df.head()
# Out:
#                   ATM Name  No Of Withdrawals  No Of XYZ Card Withdrawals  \
# Transaction Date
# 2013-11-10               3                249                         190
# 2015-11-16               3                106                          65
# 2013-07-31               0                141                         107
# 2011-01-16               0                 42                          33
# 2017-10-03               1                 67                          20
#
#                   No Of Other Card Withdrawals  Amount withdrawn XYZ Card  \
# Transaction Date
# 2013-11-10                                  59                     918200
# 2015-11-16                                  41                     366700
# 2013-07-31                                  34                     550500
# 2011-01-16                                   9                     132800
# 2017-10-03                                  47                      80300
#
#                   Amount withdrawn Other Card  Weekday  Festival Religion  \
# Transaction Date
# 2013-11-10                             283000        6                  4
# 2015-11-16                             229600        0                  4
# 2013-07-31                              72100        2                  4
# 2011-01-16                              21300        6                  1
# 2017-10-03                             127100        1                  4
#
#                   Working Day  Holiday Sequence  Year  Month  Day  Sin_Month  \
# Transaction Date
# 2013-11-10                  1                 6  2013     11   10  -0.500000
# 2015-11-16                  1                 3  2015     11   16  -0.500000
# 2013-07-31                  1                 7  2013      7   31  -0.500000
# 2011-01-16                  0                 0  2011      1   16   0.500000
# 2017-10-03                  1                 6  2017     10    3  -0.866025
#
#                   Cos_Month  Total amount Withdrawn
# Transaction Date
# 2013-11-10         0.866025                 1201200
# 2015-11-16         0.866025                  596300
# 2013-07-31        -0.866025                  622600
# 2011-01-16         0.866025                  154100
# 2017-10-03         0.500000                  207400

# %%
# Create a new column in the DataFrame for the predicted values
original_train_df['Predicted_Value'] =y_pred_rescaled.astype(int)

# Display the DataFrame with the predicted values added
original_train_df.head()
# Out:
#                   ATM Name  No Of Withdrawals  No Of XYZ Card Withdrawals  \
# Transaction Date
# 2013-11-10               3                249                         190
# 2015-11-16               3                106                          65
# 2013-07-31               0                141                         107
# 2011-01-16               0                 42                          33
# 2017-10-03               1                 67                          20
#
#                   No Of Other Card Withdrawals  Amount withdrawn XYZ Card  \
# Transaction Date
# 2013-11-10                                  59                     918200
# 2015-11-16                                  41                     366700
# 2013-07-31                                  34                     550500
# 2011-01-16                                   9                     132800
# 2017-10-03                                  47                      80300
#
#                   Amount withdrawn Other Card  Weekday  Festival Religion  \
# Transaction Date
# 2013-11-10                             283000        6                  4
# 2015-11-16                             229600        0                  4
# 2013-07-31                              72100        2                  4
# 2011-01-16                              21300        6                  1
# 2017-10-03                             127100        1                  4
#
#                   Working Day  Holiday Sequence  Year  Month  Day  Sin_Month  \
# Transaction Date
# 2013-11-10                  1                 6  2013     11   10  -0.500000
# 2015-11-16                  1                 3  2015     11   16  -0.500000
# 2013-07-31                  1                 7  2013      7   31  -0.500000
# 2011-01-16                  0                 0  2011      1   16   0.500000
# 2017-10-03                  1                 6  2017     10    3  -0.866025
#
#                   Cos_Month  Total amount Withdrawn  Predicted_Value
# Transaction Date
# 2013-11-10         0.866025                 1201200          1201200
# 2015-11-16         0.866025                  596300           596300
# 2013-07-31        -0.866025                  622600           622600
# 2011-01-16         0.866025                  154100           154099
# 2017-10-03         0.500000                  207400           207400

# %%
# Calculate individual error
original_train_df['Individual Error'] = original_train_df['Predicted_Value'] -original_train_df['Total amount Withdrawn']
# Display the DataFrame with the individual error column added
original_train_df.head()
# Out:
#                   ATM Name  No Of Withdrawals  No Of XYZ Card Withdrawals  \
# Transaction Date
# 2013-11-10               3                249                         190
# 2015-11-16               3                106                          65
# 2013-07-31               0                141                         107
# 2011-01-16               0                 42                          33
# 2017-10-03               1                 67                          20
#
#                   No Of Other Card Withdrawals  Amount withdrawn XYZ Card  \
# Transaction Date
# 2013-11-10                                  59                     918200
# 2015-11-16                                  41                     366700
# 2013-07-31                                  34                     550500
# 2011-01-16                                   9                     132800
# 2017-10-03                                  47                      80300
#
#                   Amount withdrawn Other Card  Weekday  Festival Religion  \
# Transaction Date
# 2013-11-10                             283000        6                  4
# 2015-11-16                             229600        0                  4
# 2013-07-31                              72100        2                  4
# 2011-01-16                              21300        6                  1
# 2017-10-03                             127100        1                  4
#
#                   Working Day  Holiday Sequence  Year  Month  Day  Sin_Month  \
# Transaction Date
# 2013-11-10                  1                 6  2013     11   10  -0.500000
# 2015-11-16                  1                 3  2015     11   16  -0.500000
# 2013-07-31                  1                 7  2013      7   31  -0.500000
# 2011-01-16                  0                 0  2011      1   16   0.500000
# 2017-10-03                  1                 6  2017     10    3  -0.866025
#
#                   Cos_Month  Total amount Withdrawn  Predicted_Value  \
# Transaction Date
# 2013-11-10         0.866025                 1201200          1201200
# 2015-11-16         0.866025                  596300           596300
# 2013-07-31        -0.866025                  622600           622600
# 2011-01-16         0.866025                  154100           154099
# 2017-10-03         0.500000                  207400           207400
#
#                   Individual Error
# Transaction Date
# 2013-11-10                       0
# 2015-11-16                       0
# 2013-07-31                       0
# 2011-01-16                      -1
# 2017-10-03                       0

# %% [markdown]
# # original trained data

# %%
original_train_df.to_csv("Train_adaboost_total poly.csv", index=False)

# %% [markdown]
# # TESTING

# %%
predictions = adaboost.predict(X_test_scale)
print(predictions )
# Out:
# [-0.73436614  0.82726755  0.93806122 ...  0.42618208 -1.22334379
#   0.84862164]

# %%
plt.figure(figsize=(10, 6))
plt.scatter(y_test_scale, predictions, color='blue')
plt.plot([min(y_test_scale), max(y_test_scale)], [min(y_test_scale), max(y_test_scale)], linestyle='--', color='red')
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Actual vs Predicted Values on Training Data")
plt.show()

# %% [markdown]
# # Error rate of Test Dataset

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
# Mean Squared Error (MSE)
mse = mean_squared_error(y_test_scale, predictions)
print("Mean Squared Error (MSE):", mse)

# Root Mean Squared Error (RMSE)
rmse = mean_squared_error(y_test_scale, predictions, squared=False)
print("Root Mean Squared Error (RMSE):", rmse)

# Mean Absolute Error (MAE)
mae = mean_absolute_error(y_test_scale ,predictions)
print("Mean Absolute Error (MAE):", mae)

# Coefficient of Determination (R^2 Score)
r2 = r2_score(y_test_scale, predictions)
print("Coefficient of Determination (R^2 Score):", r2)
# Out:
# Mean Squared Error (MSE): 1.0981872037611148e-31
# Root Mean Squared Error (RMSE): 3.313890770319859e-16
# Mean Absolute Error (MAE): 2.5255390438461673e-16
# Coefficient of Determination (R^2 Score): 1.0

# %%
from sklearn.preprocessing import StandardScaler

# Create a StandardScaler object

# Assuming 'predictions' contains the scaled predictions
predictions=predictions.reshape(-1,1)
# Inverse transform scaled predictions back to original scale
y_pred_rescaled = std.inverse_transform(predictions)

# Print the rescaled predictions
print(y_pred_rescaled)
# Out:
# [[282300.]
#  [786900.]
#  [822700.]
#  ...
#  [657300.]
#  [124300.]
#  [793800.]]

# %%
# Concatenate the two DataFrames side by side
original_test_df = pd.concat([X_test, y_test], axis=1)

# Display the concatenated DataFrame
original_test_df.head()
# Out:
#                   ATM Name  No Of Withdrawals  No Of XYZ Card Withdrawals  \
# Transaction Date
# 2013-02-13               1                 90                          28
# 2015-10-20               2                149                          82
# 2012-03-10               2                215                          46
# 2011-07-16               4                150                          76
# 2017-07-21               3                 45                          26
#
#                   No Of Other Card Withdrawals  Amount withdrawn XYZ Card  \
# Transaction Date
# 2013-02-13                                  62                     125100
# 2015-10-20                                  67                     517800
# 2012-03-10                                 169                     201100
# 2011-07-16                                  74                     252400
# 2017-07-21                                  19                     252100
#
#                   Amount withdrawn Other Card  Weekday  Festival Religion  \
# Transaction Date
# 2013-02-13                             157200        2                  4
# 2015-10-20                             269100        1                  4
# 2012-03-10                             621600        5                  3
# 2011-07-16                             197600        5                  4
# 2017-07-21                             106700        4                  4
#
#                   Working Day  Holiday Sequence  Year  Month  Day  Sin_Month  \
# Transaction Date
# 2013-02-13                  1                 7  2013      2   13   0.866025
# 2015-10-20                  1                 6  2015     10   20  -0.866025
# 2012-03-10                  0                 5  2012      3   10   1.000000
# 2011-07-16                  0                 1  2011      7   16  -0.500000
# 2017-07-21                  1                 6  2017      7   21  -0.500000
#
#                      Cos_Month  Total amount Withdrawn
# Transaction Date
# 2013-02-13        5.000000e-01                  282300
# 2015-10-20        5.000000e-01                  786900
# 2012-03-10        6.123234e-17                  822700
# 2011-07-16       -8.660254e-01                  450000
# 2017-07-21       -8.660254e-01                  358800

# %%
# Create a new column in the DataFrame for the predicted values
original_test_df['Predicted_Value'] =y_pred_rescaled.astype(int)

# Display the DataFrame with the predicted values added
original_test_df.head()
y_pred_rescaled
# Out:
# array([[282300.],
#        [786900.],
#        [822700.],
#        ...,
#        [657300.],
#        [124300.],
#        [793800.]])

# %%
# Calculate individual error
original_test_df['Individual Error'] =original_test_df['Predicted_Value']-original_test_df['Total amount Withdrawn']

# Display the DataFrame with the individual error column added
original_test_df.head()
# Out:
#                   ATM Name  No Of Withdrawals  No Of XYZ Card Withdrawals  \
# Transaction Date
# 2013-02-13               1                 90                          28
# 2015-10-20               2                149                          82
# 2012-03-10               2                215                          46
# 2011-07-16               4                150                          76
# 2017-07-21               3                 45                          26
#
#                   No Of Other Card Withdrawals  Amount withdrawn XYZ Card  \
# Transaction Date
# 2013-02-13                                  62                     125100
# 2015-10-20                                  67                     517800
# 2012-03-10                                 169                     201100
# 2011-07-16                                  74                     252400
# 2017-07-21                                  19                     252100
#
#                   Amount withdrawn Other Card  Weekday  Festival Religion  \
# Transaction Date
# 2013-02-13                             157200        2                  4
# 2015-10-20                             269100        1                  4
# 2012-03-10                             621600        5                  3
# 2011-07-16                             197600        5                  4
# 2017-07-21                             106700        4                  4
#
#                   Working Day  Holiday Sequence  Year  Month  Day  Sin_Month  \
# Transaction Date
# 2013-02-13                  1                 7  2013      2   13   0.866025
# 2015-10-20                  1                 6  2015     10   20  -0.866025
# 2012-03-10                  0                 5  2012      3   10   1.000000
# 2011-07-16                  0                 1  2011      7   16  -0.500000
# 2017-07-21                  1                 6  2017      7   21  -0.500000
#
#                      Cos_Month  Total amount Withdrawn  Predicted_Value  \
# Transaction Date
# 2013-02-13        5.000000e-01                  282300           282300
# 2015-10-20        5.000000e-01                  786900           786900
# 2012-03-10        6.123234e-17                  822700           822700
# 2011-07-16       -8.660254e-01                  450000           449999
# 2017-07-21       -8.660254e-01                  358800           358800
#
#                   Individual Error
# Transaction Date
# 2013-02-13                       0
# 2015-10-20                       0
# 2012-03-10                       0
# 2011-07-16                      -1
# 2017-07-21                       0

# %% [markdown]
# # Original test dataset

# %%
original_test_df.to_csv("Test_adaboost_total poly.csv", index=False)

# %%
import pickle

# Serialize the dataset and save it to a file
with open('adaboost_DT.pickle', 'wb') as f:
    pickle.dump(adaboost, f)

print("Dataset pickled and saved successfully.")
# Out:
# Dataset pickled and saved successfully.
