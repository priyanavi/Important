# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\gss\anaconda3\lib\site-packages (2.15.0)
# Requirement already satisfied: tensorflow-intel==2.15.0 in c:\users\gss\anaconda3\lib\site-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\gss\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\gss\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\gss\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\gss\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\gss\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\gss\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\gss\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in c:\users\gss\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in c:\users\gss\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.24.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\gss\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\gss\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\gss\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (4.23.4)
# Requirement already satisfied: setuptools in c:\users\gss\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\gss\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\gss\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\gss\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (4.7.1)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\gss\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\gss\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\gss\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.60.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in c:\users\gss\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.1)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in c:\users\gss\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in c:\users\gss\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\gss\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.15.0->tensorflow) (0.38.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\gss\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.25.2)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in c:\users\gss\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\gss\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\gss\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\gss\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\gss\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.2.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\gss\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\gss\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\gss\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\gss\anaconda3\lib\site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\gss\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gss\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\gss\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gss\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\gss\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\gss\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\gss\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# %%
# Load the data
df = pd.read_csv("ATM_cash_flow_data.csv")  


df.head(10)
# Out:
#              ATM Name Transaction Date  No Of Withdrawals  \
# 0      Big Street ATM         1/1/2011                 50
# 1      Mount Road ATM         1/1/2011                253
# 2         Airport ATM         1/1/2011                 98
# 3        KK Nagar ATM         1/1/2011                265
# 4  Christ College ATM         1/1/2011                 74
# 5      Big Street ATM         2/1/2011                 17
# 6      Mount Road ATM         2/1/2011                194
# 7         Airport ATM         2/1/2011                 67
# 8        KK Nagar ATM         2/1/2011                260
# 9  Christ College ATM         2/1/2011                 80
#
#    No Of XYZ Card Withdrawals  No Of Other Card Withdrawals  \
# 0                          20                            30
# 1                          67                           186
# 2                          56                            42
# 3                         159                           106
# 4                          25                            49
# 5                           5                            12
# 6                          50                           144
# 7                          53                            14
# 8                         155                           105
# 9                          24                            56
#
#    Total amount Withdrawn  Amount withdrawn XYZ Card  \
# 0                  123800                      41700
# 1                  767900                     270900
# 2                  503400                     347700
# 3                  945300                     532600
# 4                  287700                     148200
# 5                   52800                      20900
# 6                  529300                     171700
# 7                  268600                     213300
# 8                  809400                     456200
# 9                  300000                      95600
#
#    Amount withdrawn Other Card   Weekday Festival Religion Working Day  \
# 0                        82100  Saturday                 H           H
# 1                       497000  Saturday                 C           H
# 2                       155700  Saturday                 C           H
# 3                       412700  Saturday                 C           H
# 4                       139500  Saturday                 C           H
# 5                        31900    Sunday                NH           H
# 6                       357600    Sunday                NH           H
# 7                        55300    Sunday                NH           H
# 8                       353200    Sunday                NH           H
# 9                       204400    Sunday                NH           H
#
#   Holiday Sequence
# 0              HHW
# 1              HHW
# 2              HHW
# 3              HHW
# 4              HHW
# 5              HHW
# 6              HHW
# 7              HHW
# 8              HHW
# 9              HHW

# %%
df.isnull().sum()
# Out:
# ATM Name                        0
# Transaction Date                0
# No Of Withdrawals               0
# No Of XYZ Card Withdrawals      0
# No Of Other Card Withdrawals    0
# Total amount Withdrawn          0
# Amount withdrawn XYZ Card       0
# Amount withdrawn Other Card     0
# Weekday                         0
# Festival Religion               0
# Working Day                     0
# Holiday Sequence                0
# dtype: int64

# %%
# Convert 'Transaction Date' to datetime format
df['Transaction Date'] = pd.to_datetime(df['Transaction Date'])
df.tail(10)
# Out:
#                  ATM Name Transaction Date  No Of Withdrawals  \
# 11579      Big Street ATM       2017-09-28                137
# 11580      Mount Road ATM       2017-09-28                 87
# 11581         Airport ATM       2017-09-28                 68
# 11582        KK Nagar ATM       2017-09-28                145
# 11583  Christ College ATM       2017-09-28                187
# 11584      Big Street ATM       2017-09-29                137
# 11585      Mount Road ATM       2017-09-29                 79
# 11586         Airport ATM       2017-09-29                117
# 11587        KK Nagar ATM       2017-09-29                 76
# 11588  Christ College ATM       2017-09-29                143
#
#        No Of XYZ Card Withdrawals  No Of Other Card Withdrawals  \
# 11579                          41                            96
# 11580                          28                            59
# 11581                          47                            21
# 11582                          97                            48
# 11583                          76                           111
# 11584                          34                           103
# 11585                          27                            52
# 11586                          77                            40
# 11587                          48                            28
# 11588                          61                            82
#
#        Total amount Withdrawn  Amount withdrawn XYZ Card  \
# 11579                  468600                     221800
# 11580                  317400                     164900
# 11581                  424700                     299500
# 11582                 1154900                     905400
# 11583                 1120300                     549100
# 11584                  468800                     146200
# 11585                  305100                     172500
# 11586                  709900                     576800
# 11587                  408700                     279900
# 11588                  700400                     364200
#
#        Amount withdrawn Other Card  Weekday Festival Religion Working Day  \
# 11579                       246800        3                NH           W
# 11580                       152500        3                NH           W
# 11581                       125200        3                NH           W
# 11582                       249500        3                NH           W
# 11583                       571200        3                NH           W
# 11584                       322600        4                 H           H
# 11585                       132600        4                 H           H
# 11586                       133100        4                 H           H
# 11587                       128800        4                 H           H
# 11588                       336200        4                 H           H
#
#       Holiday Sequence  Year  Month  Day
# 11579              WWH  2017      9   28
# 11580              WWH  2017      9   28
# 11581              WWH  2017      9   28
# 11582              WWH  2017      9   28
# 11583              WWH  2017      9   28
# 11584              WHH  2017      9   29
# 11585              WHH  2017      9   29
# 11586              WHH  2017      9   29
# 11587              WHH  2017      9   29
# 11588              WHH  2017      9   29

# %%
# Convert the 'Transaction Date' column to datetime format
df['Transaction Date'] = pd.to_datetime(df['Transaction Date'], format="%d-%m-%Y")

# Create new columns for Year, Month, Day, and Weekday
df['Year'] = df['Transaction Date'].dt.year
df['Month'] = df['Transaction Date'].dt.month
df['Day'] = df['Transaction Date'].dt.day
df['Weekday'] = df['Transaction Date'].dt.dayofweek

# %%
df.tail(10)
# Out:
#              ATM Name Transaction Date  No Of Withdrawals  \
# 0      Big Street ATM       2011-01-01                 50
# 1      Mount Road ATM       2011-01-01                253
# 2         Airport ATM       2011-01-01                 98
# 3        KK Nagar ATM       2011-01-01                265
# 4  Christ College ATM       2011-01-01                 74
#
#    No Of XYZ Card Withdrawals  No Of Other Card Withdrawals  \
# 0                          20                            30
# 1                          67                           186
# 2                          56                            42
# 3                         159                           106
# 4                          25                            49
#
#    Total amount Withdrawn  Amount withdrawn XYZ Card  \
# 0                  123800                      41700
# 1                  767900                     270900
# 2                  503400                     347700
# 3                  945300                     532600
# 4                  287700                     148200
#
#    Amount withdrawn Other Card  Weekday Festival Religion Working Day  \
# 0                        82100        5                 H           H
# 1                       497000        5                 C           H
# 2                       155700        5                 C           H
# 3                       412700        5                 C           H
# 4                       139500        5                 C           H
#
#   Holiday Sequence  Year  Month  Day
# 0              HHW  2011      1    1
# 1              HHW  2011      1    1
# 2              HHW  2011      1    1
# 3              HHW  2011      1    1
# 4              HHW  2011      1    1

# %%
# Create new columns for sin and cos waves for the month
df['Sin_Month'] = np.sin(2 * np.pi * df['Month'] / 12)
df['Cos_Month'] = np.cos(2 * np.pi * df['Month'] / 12)

df.head()
# Out:
#              ATM Name Transaction Date  No Of Withdrawals  \
# 0      Big Street ATM       2011-01-01                 50
# 1      Mount Road ATM       2011-01-01                253
# 2         Airport ATM       2011-01-01                 98
# 3        KK Nagar ATM       2011-01-01                265
# 4  Christ College ATM       2011-01-01                 74
#
#    No Of XYZ Card Withdrawals  No Of Other Card Withdrawals  \
# 0                          20                            30
# 1                          67                           186
# 2                          56                            42
# 3                         159                           106
# 4                          25                            49
#
#    Total amount Withdrawn  Amount withdrawn XYZ Card  \
# 0                  123800                      41700
# 1                  767900                     270900
# 2                  503400                     347700
# 3                  945300                     532600
# 4                  287700                     148200
#
#    Amount withdrawn Other Card  Weekday Festival Religion Working Day  \
# 0                        82100        5                 H           H
# 1                       497000        5                 C           H
# 2                       155700        5                 C           H
# 3                       412700        5                 C           H
# 4                       139500        5                 C           H
#
#   Holiday Sequence  Year  Month  Day  Sin_Month  Cos_Month
# 0              HHW  2011      1    1        0.5   0.866025
# 1              HHW  2011      1    1        0.5   0.866025
# 2              HHW  2011      1    1        0.5   0.866025
# 3              HHW  2011      1    1        0.5   0.866025
# 4              HHW  2011      1    1        0.5   0.866025

# %%
# Plot the sine and cosine waves
plt.figure(figsize=(10, 6))
plt.plot(df['Transaction Date'], df['Sin_Month'], label='Sin Wave')
plt.plot(df['Transaction Date'], df['Cos_Month'], label='Cos Wave')

plt.title('Sin and Cos Waves for the Month')
plt.xlabel('Transaction Date')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['Transaction Date'], df['Sin_Month'], label='Sin Wave', marker='o')
plt.scatter(df['Transaction Date'], df['Cos_Month'], label='Cos Wave', marker='x')

plt.title('Sin and Cos Waves for the Month')
plt.xlabel('Transaction Date')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(10, 8), sharex=True)

axes[0].plot(df['Transaction Date'], df['Sin_Month'], label='Sin Wave')
axes[0].set_ylabel('Sin Value')
axes[0].legend()

axes[1].plot(df['Transaction Date'], df['Cos_Month'], label='Cos Wave', color='orange')
axes[1].set_xlabel('Transaction Date')
axes[1].set_ylabel('Cos Value')
axes[1].legend()

plt.suptitle('Sin and Cos Waves for the Month')
plt.show()

# %%
# Assuming 'df' is your DataFrame
df.set_index('Transaction Date', inplace=True)

# %%
df.head()
# Out:
#                             ATM Name  No Of Withdrawals  \
# Transaction Date
# 2011-01-01            Big Street ATM                 50
# 2011-01-01            Mount Road ATM                253
# 2011-01-01               Airport ATM                 98
# 2011-01-01              KK Nagar ATM                265
# 2011-01-01        Christ College ATM                 74
#
#                   No Of XYZ Card Withdrawals  No Of Other Card Withdrawals  \
# Transaction Date
# 2011-01-01                                20                            30
# 2011-01-01                                67                           186
# 2011-01-01                                56                            42
# 2011-01-01                               159                           106
# 2011-01-01                                25                            49
#
#                   Total amount Withdrawn  Amount withdrawn XYZ Card  \
# Transaction Date
# 2011-01-01                        123800                      41700
# 2011-01-01                        767900                     270900
# 2011-01-01                        503400                     347700
# 2011-01-01                        945300                     532600
# 2011-01-01                        287700                     148200
#
#                   Amount withdrawn Other Card  Weekday Festival Religion  \
# Transaction Date
# 2011-01-01                              82100        5                 H
# 2011-01-01                             497000        5                 C
# 2011-01-01                             155700        5                 C
# 2011-01-01                             412700        5                 C
# 2011-01-01                             139500        5                 C
#
#                  Working Day Holiday Sequence  Year  Month  Day  Sin_Month  \
# Transaction Date
# 2011-01-01                 H              HHW  2011      1    1        0.5
# 2011-01-01                 H              HHW  2011      1    1        0.5
# 2011-01-01                 H              HHW  2011      1    1        0.5
# 2011-01-01                 H              HHW  2011      1    1        0.5
# 2011-01-01                 H              HHW  2011      1    1        0.5
#
#                   Cos_Month
# Transaction Date
# 2011-01-01         0.866025
# 2011-01-01         0.866025
# 2011-01-01         0.866025
# 2011-01-01         0.866025
# 2011-01-01         0.866025

# %%
df.count()
# Out:
# ATM Name                        11589
# No Of Withdrawals               11589
# No Of XYZ Card Withdrawals      11589
# No Of Other Card Withdrawals    11589
# Total amount Withdrawn          11589
# Amount withdrawn XYZ Card       11589
# Amount withdrawn Other Card     11589
# Weekday                         11589
# Festival Religion               11589
# Working Day                     11589
# Holiday Sequence                11589
# Year                            11589
# Month                           11589
# Day                             11589
# Sin_Month                       11589
# Cos_Month                       11589
# dtype: int64

# %%
# Assuming 'df' is your DataFrame
df.drop_duplicates(inplace=True)

# %%
df.count()
# Out:
# ATM Name                        11589
# No Of Withdrawals               11589
# No Of XYZ Card Withdrawals      11589
# No Of Other Card Withdrawals    11589
# Total amount Withdrawn          11589
# Amount withdrawn XYZ Card       11589
# Amount withdrawn Other Card     11589
# Weekday                         11589
# Festival Religion               11589
# Working Day                     11589
# Holiday Sequence                11589
# Year                            11589
# Month                           11589
# Day                             11589
# Sin_Month                       11589
# Cos_Month                       11589
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 11589 entries, 2011-01-01 to 2017-09-29
# Data columns (total 16 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ATM Name                      11589 non-null  object
#  1   No Of Withdrawals             11589 non-null  int64
#  2   No Of XYZ Card Withdrawals    11589 non-null  int64
#  3   No Of Other Card Withdrawals  11589 non-null  int64
#  4   Total amount Withdrawn        11589 non-null  int64
#  5   Amount withdrawn XYZ Card     11589 non-null  int64
#  6   Amount withdrawn Other Card   11589 non-null  int64
#  7   Weekday                       11589 non-null  int32
#  8   Festival Religion             11589 non-null  object
#  9   Working Day                   11589 non-null  object
#  10  Holiday Sequence              11589 non-null  object
#  11  Year                          11589 non-null  int32
#  12  Month                         11589 non-null  int32
#  13  Day                           11589 non-null  int32
#  14  Sin_Month                     11589 non-null  float64
#  15  Cos_Month                     11589 non-null  float64
# dtypes: float64(2), int32(4), int64(6), object(4)
# memory usage: 1.3+ MB

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
# Specify columns containing string values that need to be encoded
columns_to_encode = ['ATM Name','Working Day', 'Festival Religion','Holiday Sequence']

# Use LabelEncoder to encode string values to numeric
label_encoder = LabelEncoder()
for column in columns_to_encode:
    df[column] = label_encoder.fit_transform(df[column])

# %%
df.head()
# Out:
#                   ATM Name  No Of Withdrawals  No Of XYZ Card Withdrawals  \
# Transaction Date
# 2011-01-01               1                 50                          20
# 2011-01-01               4                253                          67
# 2011-01-01               0                 98                          56
# 2011-01-01               3                265                         159
# 2011-01-01               2                 74                          25
#
#                   No Of Other Card Withdrawals  Total amount Withdrawn  \
# Transaction Date
# 2011-01-01                                  30                  123800
# 2011-01-01                                 186                  767900
# 2011-01-01                                  42                  503400
# 2011-01-01                                 106                  945300
# 2011-01-01                                  49                  287700
#
#                   Amount withdrawn XYZ Card  Amount withdrawn Other Card  \
# Transaction Date
# 2011-01-01                            41700                        82100
# 2011-01-01                           270900                       497000
# 2011-01-01                           347700                       155700
# 2011-01-01                           532600                       412700
# 2011-01-01                           148200                       139500
#
#                   Weekday  Festival Religion  Working Day  Holiday Sequence  \
# Transaction Date
# 2011-01-01              5                  1            0                 1
# 2011-01-01              5                  0            0                 1
# 2011-01-01              5                  0            0                 1
# 2011-01-01              5                  0            0                 1
# 2011-01-01              5                  0            0                 1
#
#                   Year  Month  Day  Sin_Month  Cos_Month
# Transaction Date
# 2011-01-01        2011      1    1        0.5   0.866025
# 2011-01-01        2011      1    1        0.5   0.866025
# 2011-01-01        2011      1    1        0.5   0.866025
# 2011-01-01        2011      1    1        0.5   0.866025
# 2011-01-01        2011      1    1        0.5   0.866025

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 11589 entries, 2011-01-01 to 2017-09-29
# Data columns (total 16 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ATM Name                      11589 non-null  int32
#  1   No Of Withdrawals             11589 non-null  int64
#  2   No Of XYZ Card Withdrawals    11589 non-null  int64
#  3   No Of Other Card Withdrawals  11589 non-null  int64
#  4   Total amount Withdrawn        11589 non-null  int64
#  5   Amount withdrawn XYZ Card     11589 non-null  int64
#  6   Amount withdrawn Other Card   11589 non-null  int64
#  7   Weekday                       11589 non-null  int32
#  8   Festival Religion             11589 non-null  int32
#  9   Working Day                   11589 non-null  int32
#  10  Holiday Sequence              11589 non-null  int32
#  11  Year                          11589 non-null  int32
#  12  Month                         11589 non-null  int32
#  13  Day                           11589 non-null  int32
#  14  Sin_Month                     11589 non-null  float64
#  15  Cos_Month                     11589 non-null  float64
# dtypes: float64(2), int32(8), int64(6)
# memory usage: 1.1 MB

# %%
df.columns
# Out:
# Index(['ATM Name', 'No Of Withdrawals', 'No Of XYZ Card Withdrawals',
#        'No Of Other Card Withdrawals', 'Total amount Withdrawn',
#        'Amount withdrawn XYZ Card', 'Amount withdrawn Other Card', 'Weekday',
#        'Festival Religion', 'Working Day', 'Holiday Sequence', 'Year', 'Month',
#        'Day', 'Sin_Month', 'Cos_Month'],
#       dtype='object')

# %%
# Remove and return the column 'Total amount Withdrawn', and then reinsert it at the last position
df['Total amount Withdrawn'] = df.pop('Total amount Withdrawn')

# %%
df.describe()
# Out:
#            ATM Name  No Of Withdrawals  No Of XYZ Card Withdrawals  \
# count  11589.000000       11589.000000                11589.000000
# mean       2.001985         123.341099                   67.567694
# std        1.401493          67.315288                   47.849517
# min        0.000000           1.000000                    0.000000
# 25%        1.000000          79.000000                   34.000000
# 50%        2.000000         115.000000                   57.000000
# 75%        3.000000         158.000000                   87.000000
# max        4.000000         491.000000                  345.000000
#
#        No Of Other Card Withdrawals  Amount withdrawn XYZ Card  \
# count                  11589.000000               1.158900e+04
# mean                      55.773406               3.345604e+05
# std                       38.506475               2.470771e+05
# min                        0.000000               0.000000e+00
# 25%                       25.000000               1.560000e+05
# 50%                       50.000000               2.816000e+05
# 75%                       78.000000               4.485000e+05
# max                      310.000000               1.907800e+06
#
#        Amount withdrawn Other Card       Weekday  Festival Religion  \
# count                 1.158900e+04  11589.000000       11589.000000
# mean                  1.877455e+05      2.989300           3.816119
# std                   1.502351e+05      1.996473           0.702893
# min                   0.000000e+00      0.000000           0.000000
# 25%                   7.910000e+04      1.000000           4.000000
# 50%                   1.586000e+05      3.000000           4.000000
# 75%                   2.560000e+05      5.000000           4.000000
# max                   1.472600e+06      6.000000           4.000000
#
#         Working Day  Holiday Sequence          Year         Month  \
# count  11589.000000      11589.000000  11589.000000  11589.000000
# mean       0.571318          3.862801   2013.760549      6.346967
# std        0.494909          2.657368      1.920326      3.375119
# min        0.000000          0.000000   2011.000000      1.000000
# 25%        0.000000          1.000000   2012.000000      3.000000
# 50%        1.000000          3.000000   2014.000000      6.000000
# 75%        1.000000          7.000000   2015.000000      9.000000
# max        1.000000          7.000000   2017.000000     12.000000
#
#                 Day     Sin_Month     Cos_Month  Total amount Withdrawn
# count  11589.000000  1.158900e+04  1.158900e+04            1.158900e+04
# mean      15.714471  5.952484e-03 -3.537544e-02            5.223059e+05
# std        8.877120  7.138987e-01  6.993912e-01            3.248167e+05
# min        1.000000 -1.000000e+00 -1.000000e+00            1.000000e+02
# 25%        8.000000 -8.660254e-01 -8.660254e-01            3.057000e+05
# 50%       16.000000  1.224647e-16 -1.836970e-16            4.700000e+05
# 75%       23.000000  8.660254e-01  5.000000e-01            6.716000e+05
# max       31.000000  1.000000e+00  1.000000e+00            2.549800e+06

# %%
X = df.drop('Total amount Withdrawn' , axis = 1) # Features are all columns except the last one
y = df["Total amount Withdrawn"]   # Target variable is the last column

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, test_size=0.1)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, random_state=1, test_size=0.1)

# %%
X_train
# Out:
#                   ATM Name  No Of Withdrawals  No Of XYZ Card Withdrawals  \
# Transaction Date
# 2012-03-25               4                113                          26
# 2017-01-19               3                 30                          20
# 2013-05-30               0                103                          84
# 2011-12-22               1                 46                          28
# 2015-12-23               3                166                         116
# ...                    ...                ...                         ...
# 2011-09-22               4                147                          72
# 2014-06-30               2                133                          60
# 2016-04-20               3                130                          92
# 2014-10-16               3                298                         208
# 2014-04-21               4                213                         108
#
#                   No Of Other Card Withdrawals  Amount withdrawn XYZ Card  \
# Transaction Date
# 2012-03-25                                  87                     120900
# 2017-01-19                                  10                      32800
# 2013-05-30                                  19                     368100
# 2011-12-22                                  18                     127200
# 2015-12-23                                  50                     734700
# ...                                        ...                        ...
# 2011-09-22                                  75                     184100
# 2014-06-30                                  73                     288500
# 2016-04-20                                  38                     631800
# 2014-10-16                                  90                    1003700
# 2014-04-21                                 105                     709300
#
#                   Amount withdrawn Other Card  Weekday  Festival Religion  \
# Transaction Date
# 2012-03-25                             154200        6                  4
# 2017-01-19                              13700        3                  4
# 2013-05-30                              31400        3                  4
# 2011-12-22                              59600        3                  4
# 2015-12-23                             254200        2                  4
# ...                                       ...      ...                ...
# 2011-09-22                             173200        3                  4
# 2014-06-30                             338900        0                  4
# 2016-04-20                             204000        2                  4
# 2014-10-16                             362600        3                  4
# 2014-04-21                             348000        0                  4
#
#                   Working Day  Holiday Sequence  Year  Month  Day  \
# Transaction Date
# 2012-03-25                  0                 1  2012      3   25
# 2017-01-19                  1                 7  2017      1   19
# 2013-05-30                  1                 7  2013      5   30
# 2011-12-22                  1                 7  2011     12   22
# 2015-12-23                  1                 7  2015     12   23
# ...                       ...               ...   ...    ...  ...
# 2011-09-22                  1                 7  2011      9   22
# 2014-06-30                  1                 3  2014      6   30
# 2016-04-20                  1                 3  2016      4   20
# 2014-10-16                  1                 7  2014     10   16
# 2014-04-21                  1                 3  2014      4   21
#
#                      Sin_Month     Cos_Month
# Transaction Date
# 2012-03-25        1.000000e+00  6.123234e-17
# 2017-01-19        5.000000e-01  8.660254e-01
# 2013-05-30        5.000000e-01 -8.660254e-01
# 2011-12-22       -2.449294e-16  1.000000e+00
# 2015-12-23       -2.449294e-16  1.000000e+00
# ...                        ...           ...
# 2011-09-22       -1.000000e+00 -1.836970e-16
# 2014-06-30        1.224647e-16 -1.000000e+00
# 2016-04-20        8.660254e-01 -5.000000e-01
# 2014-10-16       -8.660254e-01  5.000000e-01
# 2014-04-21        8.660254e-01 -5.000000e-01
#
# [9387 rows x 15 columns]

# %%
y_train
# Out:
# Transaction Date
# 2012-03-25     275100
# 2017-01-19      46500
# 2013-05-30     399500
# 2011-12-22     186800
# 2015-12-23     988900
#                ...
# 2011-09-22     357300
# 2014-06-30     627400
# 2016-04-20     835800
# 2014-10-16    1366300
# 2014-04-21    1057300
# Name: Total amount Withdrawn, Length: 9387, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
std = StandardScaler()
X_train_scale= std.fit_transform(X_train)
X_val_scale= std.fit_transform(X_val)
X_test_scale= std.fit_transform(X_test)

# %%
# Assuming y_train, y_val, and y_test are pandas Series objects
# Convert them to numpy arrays
y_train_np = y_train.to_numpy().reshape(-1, 1)
y_val_np = y_val.to_numpy().reshape(-1, 1)
y_test_np = y_test.to_numpy().reshape(-1, 1)


y_train_scale= std.fit_transform(y_train_np)
y_val_scale= std.fit_transform(y_val_np)
y_test_scale= std.fit_transform(y_test_np)

# %%
y_train_scale
# Out:
# array([[-0.76069351],
#        [-1.4607151 ],
#        [-0.37975437],
#        ...,
#        [ 0.95628858],
#        [ 2.58079188],
#        [ 1.63456847]])

# %%
# reshape input of the LSTM model from 2D to 3D
X_train_reshape = X_train_scale.reshape((X_train_scale.shape[0], 1, X_train_scale.shape[1]))
X_val_reshape = X_val_scale.reshape((X_val_scale.shape[0], 1, X_val_scale.shape[1]))
X_test_reshape =X_test_scale.reshape((X_test_scale.shape[0], 1, X_test_scale.shape[1]))

print(X_train_reshape.shape)
print(X_val_reshape.shape)
print(X_test_reshape.shape)
# Out:
# (9387, 1, 15)
# (1043, 1, 15)
# (1159, 1, 15)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout
# Out:
# WARNING:tensorflow:From C:\Users\gss\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
model = Sequential()

model.add(LSTM(units=50, return_sequences = True, input_shape = (1, 15)))
model.add(Dropout(0.2))

model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))

model.add(LSTM(units=50, return_sequences = True))
model.add(Dropout(0.2))

model.add(LSTM(units=50, return_sequences = False))
model.add(Dropout(0.2))

model.add(Dense(units =1))
model.compile(optimizer='adam',loss="mean_squared_error")
# Out:
# WARNING:tensorflow:From C:\Users\gss\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\gss\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
from keras.callbacks import EarlyStopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)
history = model.fit(X_train_reshape, y_train_scale, epochs = 100, batch_size =1000 , validation_data = (X_val_reshape, y_val_scale), callbacks = [es])
# Out:
# Epoch 1/100
# WARNING:tensorflow:From C:\Users\gss\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 10/10 [==============================] - 13s 276ms/step - loss: 0.9978 - val_loss: 0.9928
# Epoch 2/100
# 10/10 [==============================] - 0s 23ms/step - loss: 0.9847 - val_loss: 0.9668
# Epoch 3/100
# 10/10 [==============================] - 0s 21ms/step - loss: 0.9382 - val_loss: 0.8709
# Epoch 4/100
# 10/10 [==============================] - 0s 22ms/step - loss: 0.7737 - val_loss: 0.5768
# Epoch 5/100
# 10/10 [==============================] - 0s 23ms/step - loss: 0.4215 - val_loss: 0.2640
# Epoch 6/100
# 10/10 [==============================] - 0s 23ms/step - loss: 0.2541 - val_loss: 0.1688
# Epoch 7/100
# 10/10 [==============================] - 0s 23ms/step - loss: 0.1712 - val_loss: 0.1391
# Epoch 8/100
# 10/10 [==============================] - 0s 23ms/step - loss: 0.1419 - val_loss: 0.1055
# Epoch 9/100
# 10/10 [==============================] - 0s 23ms/step - loss: 0.1144 - val_loss: 0.0812
# Epoch 10/100
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0940 - val_loss: 0.0674
# Epoch 11/100
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0849 - val_loss: 0.0560
# Epoch 12/100
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0765 - val_loss: 0.0481
# Epoch 13/100
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0687 - val_loss: 0.0412
# Epoch 14/100
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0630 - val_loss: 0.0355
# Epoch 15/100
# 10/10 [==============================] - 0s 24ms/step - loss: 0.0579 - val_loss: 0.0306
# Epoch 16/100
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0518 - val_loss: 0.0260
# Epoch 17/100
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0481 - val_loss: 0.0214
# Epoch 18/100
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0447 - val_loss: 0.0183
# Epoch 19/100
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0410 - val_loss: 0.0150
# Epoch 20/100
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0375 - val_loss: 0.0124
# Epoch 21/100
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0368 - val_loss: 0.0108
# Epoch 22/100
# 10/10 [==============================] - 0s 24ms/step - loss: 0.0362 - val_loss: 0.0089
# Epoch 23/100
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0332 - val_loss: 0.0078
# Epoch 24/100
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0317 - val_loss: 0.0066
# Epoch 25/100
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0312 - val_loss: 0.0055
# Epoch 26/100
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0294 - val_loss: 0.0051
# Epoch 27/100
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0289 - val_loss: 0.0047
# Epoch 28/100
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0276 - val_loss: 0.0042
# Epoch 29/100
# 10/10 [==============================] - 0s 24ms/step - loss: 0.0285 - val_loss: 0.0051
# Epoch 30/100
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0280 - val_loss: 0.0033
# Epoch 31/100
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0265 - val_loss: 0.0032
# Epoch 32/100
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0258 - val_loss: 0.0037
# Epoch 33/100
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0268 - val_loss: 0.0027
# Epoch 34/100
# 10/10 [==============================] - 0s 24ms/step - loss: 0.0274 - val_loss: 0.0029
# Epoch 35/100
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0250 - val_loss: 0.0028
# Epoch 36/100
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0254 - val_loss: 0.0024
# Epoch 37/100
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0267 - val_loss: 0.0029
# Epoch 38/100
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0243 - val_loss: 0.0020
# Epoch 39/100
# 10/10 [==============================] - 0s 22ms/step - loss: 0.0229 - val_loss: 0.0027
# Epoch 40/100
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0245 - val_loss: 0.0018
# Epoch 41/100
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0251 - val_loss: 0.0017
# Epoch 42/100
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0245 - val_loss: 0.0020
# Epoch 43/100
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0239 - val_loss: 0.0020
# Epoch 44/100
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0230 - val_loss: 0.0020
# Epoch 45/100
# 10/10 [==============================] - 0s 24ms/step - loss: 0.0220 - val_loss: 0.0016
# Epoch 46/100
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0226 - val_loss: 0.0019
# Epoch 47/100
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0234 - val_loss: 0.0022
# Epoch 48/100
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0222 - val_loss: 0.0014
# Epoch 49/100
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0225 - val_loss: 0.0014
# Epoch 50/100
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0224 - val_loss: 0.0017
# Epoch 51/100
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0223 - val_loss: 0.0016
# Epoch 52/100
# 10/10 [==============================] - 0s 24ms/step - loss: 0.0218 - val_loss: 0.0013
# Epoch 53/100
# 10/10 [==============================] - 0s 24ms/step - loss: 0.0205 - val_loss: 0.0015
# Epoch 54/100
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0219 - val_loss: 0.0012
# Epoch 55/100
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0207 - val_loss: 0.0015
# Epoch 56/100
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0227 - val_loss: 0.0014
# Epoch 57/100
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0219 - val_loss: 0.0012
# Epoch 58/100
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0206 - val_loss: 0.0012
# Epoch 59/100
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0211 - val_loss: 0.0013
# Epoch 60/100
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0202 - val_loss: 0.0011
# Epoch 61/100
# 10/10 [==============================] - 0s 24ms/step - loss: 0.0206 - val_loss: 0.0010
# Epoch 62/100
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0206 - val_loss: 0.0012
# Epoch 63/100
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0211 - val_loss: 0.0012
# Epoch 64/100
# 10/10 [==============================] - 0s 22ms/step - loss: 0.0202 - val_loss: 8.8914e-04
# Epoch 65/100
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0209 - val_loss: 8.7823e-04
# Epoch 66/100
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0200 - val_loss: 0.0011
# Epoch 67/100
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0202 - val_loss: 0.0013
# Epoch 68/100
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0193 - val_loss: 8.4633e-04
# Epoch 69/100
# 10/10 [==============================] - 0s 22ms/step - loss: 0.0199 - val_loss: 9.8688e-04
# Epoch 70/100
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0190 - val_loss: 8.9187e-04
# Epoch 71/100
# 10/10 [==============================] - 0s 22ms/step - loss: 0.0210 - val_loss: 7.9664e-04
# Epoch 72/100
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0196 - val_loss: 9.1562e-04
# Epoch 73/100
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0192 - val_loss: 9.8032e-04
# Epoch 74/100
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0195 - val_loss: 0.0014
# Epoch 75/100
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0190 - val_loss: 7.5113e-04
# Epoch 76/100
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0193 - val_loss: 0.0011
# Epoch 77/100
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0207 - val_loss: 0.0029
# Epoch 78/100
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0196 - val_loss: 9.5168e-04
# Epoch 79/100
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0201 - val_loss: 0.0013
# Epoch 80/100
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0204 - val_loss: 0.0017
# Epoch 80: early stopping

# %%
from matplotlib import pyplot
# plot loss during training

pyplot.subplot(211)
pyplot.title('Loss')
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()

# %% [markdown]
# # TRAIN DATASET

# %%
# Obtain predictions on the training data
y_train_pred = model.predict(X_train_reshape)
print(y_train_pred)
# Out:
# 294/294 [==============================] - 3s 2ms/step
# [[-0.7462632 ]
#  [-1.3665785 ]
#  [-0.35767698]
#  ...
#  [ 0.932268  ]
#  [ 2.5977104 ]
#  [ 1.601798  ]]

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
import matplotlib.pyplot as plt

# Calculate evaluation metrics
mse = mean_squared_error(y_train_scale, y_train_pred)
mae = mean_absolute_error(y_train_scale, y_train_pred)

print("Mean Squared Error (MSE) on training data:", mse)
print("Mean Absolute Error (MAE) on training data:", mae)
# Out:
# Mean Squared Error (MSE) on training data: 0.0019266652862221928
# Mean Absolute Error (MAE) on training data: 0.027443293152447357

# %%
# Plot actual vs predicted values
plt.figure(figsize=(10, 6))
plt.scatter(y_train_scale, y_train_pred, color='blue')
plt.plot([min(y_train_scale), max(y_train_scale)], [min(y_train_scale), max(y_train_scale)], linestyle='--', color='red')
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Actual vs Predicted Values on Training Data")
plt.show()

# %%
import matplotlib.pyplot as plt

# Plot actual vs predicted values with time series format
plt.figure(figsize=(12, 6))
plt.plot(range(len(y_train_scale)), y_train_scale, label='Actual', color='blue')
plt.plot(range(len(y_train_pred)), y_train_pred, label='Predicted', color='red', linestyle='--')
plt.xlabel('Index')
plt.ylabel('Value')
plt.title('Actual vs Predicted Values')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# Plot actual vs predicted values using a scatter plot
plt.figure(figsize=(12, 6))
plt.scatter(range(len(y_train_scale)), y_train_scale, label='Actual', color='blue', marker='.')
plt.scatter(range(len(y_train_pred)), y_train_pred, label='Predicted', color='red', marker='.')
plt.xlabel('Index')
plt.ylabel('Value')
plt.title('Actual vs Predicted Values')
plt.legend()
plt.show()

# %%
y_train_rescaled = std.inverse_transform(y_train_pred)


print(y_train_rescaled)
# Out:
# [[ 281179.88]
#  [  84814.06]
#  [ 404190.  ]
#  ...
#  [ 812532.5 ]
#  [1339741.8 ]
#  [1024477.6 ]]

# %%
# Concatenate the two DataFrames side by side
original_train_df = pd.concat([X_train, y_train], axis=1)

# Display the concatenated DataFrame
original_train_df.head()
# Out:
#                   ATM Name  No Of Withdrawals  No Of XYZ Card Withdrawals  \
# Transaction Date
# 2012-03-25               4                113                          26
# 2017-01-19               3                 30                          20
# 2013-05-30               0                103                          84
# 2011-12-22               1                 46                          28
# 2015-12-23               3                166                         116
#
#                   No Of Other Card Withdrawals  Amount withdrawn XYZ Card  \
# Transaction Date
# 2012-03-25                                  87                     120900
# 2017-01-19                                  10                      32800
# 2013-05-30                                  19                     368100
# 2011-12-22                                  18                     127200
# 2015-12-23                                  50                     734700
#
#                   Amount withdrawn Other Card  Weekday  Festival Religion  \
# Transaction Date
# 2012-03-25                             154200        6                  4
# 2017-01-19                              13700        3                  4
# 2013-05-30                              31400        3                  4
# 2011-12-22                              59600        3                  4
# 2015-12-23                             254200        2                  4
#
#                   Working Day  Holiday Sequence  Year  Month  Day  \
# Transaction Date
# 2012-03-25                  0                 1  2012      3   25
# 2017-01-19                  1                 7  2017      1   19
# 2013-05-30                  1                 7  2013      5   30
# 2011-12-22                  1                 7  2011     12   22
# 2015-12-23                  1                 7  2015     12   23
#
#                      Sin_Month     Cos_Month  Total amount Withdrawn
# Transaction Date
# 2012-03-25        1.000000e+00  6.123234e-17                  275100
# 2017-01-19        5.000000e-01  8.660254e-01                   46500
# 2013-05-30        5.000000e-01 -8.660254e-01                  399500
# 2011-12-22       -2.449294e-16  1.000000e+00                  186800
# 2015-12-23       -2.449294e-16  1.000000e+00                  988900

# %%
# Create a new column in the DataFrame for the predicted values
original_train_df['Predicted_Value'] = y_train_rescaled

# Display the DataFrame with the predicted values added
original_train_df.head()
# Out:
#                   ATM Name  No Of Withdrawals  No Of XYZ Card Withdrawals  \
# Transaction Date
# 2012-03-25               4                113                          26
# 2017-01-19               3                 30                          20
# 2013-05-30               0                103                          84
# 2011-12-22               1                 46                          28
# 2015-12-23               3                166                         116
#
#                   No Of Other Card Withdrawals  Amount withdrawn XYZ Card  \
# Transaction Date
# 2012-03-25                                  87                     120900
# 2017-01-19                                  10                      32800
# 2013-05-30                                  19                     368100
# 2011-12-22                                  18                     127200
# 2015-12-23                                  50                     734700
#
#                   Amount withdrawn Other Card  Weekday  Festival Religion  \
# Transaction Date
# 2012-03-25                             154200        6                  4
# 2017-01-19                              13700        3                  4
# 2013-05-30                              31400        3                  4
# 2011-12-22                              59600        3                  4
# 2015-12-23                             254200        2                  4
#
#                   Working Day  Holiday Sequence  Year  Month  Day  \
# Transaction Date
# 2012-03-25                  0                 1  2012      3   25
# 2017-01-19                  1                 7  2017      1   19
# 2013-05-30                  1                 7  2013      5   30
# 2011-12-22                  1                 7  2011     12   22
# 2015-12-23                  1                 7  2015     12   23
#
#                      Sin_Month     Cos_Month  Total amount Withdrawn  \
# Transaction Date
# 2012-03-25        1.000000e+00  6.123234e-17                  275100
# 2017-01-19        5.000000e-01  8.660254e-01                   46500
# 2013-05-30        5.000000e-01 -8.660254e-01                  399500
# 2011-12-22       -2.449294e-16  1.000000e+00                  186800
# 2015-12-23       -2.449294e-16  1.000000e+00                  988900
#
#                   Predicted_Value
# Transaction Date
# 2012-03-25            281179.8750
# 2017-01-19             84814.0625
# 2013-05-30            404190.0000
# 2011-12-22            195725.0625
# 2015-12-23            955349.5625

# %%
# Calculate individual error
original_train_df['Individual Error'] =original_train_df['Predicted_Value'] - original_train_df['Total amount Withdrawn']

# Display the DataFrame with the individual error column added
original_train_df.head()
# Out:
#                   ATM Name  No Of Withdrawals  No Of XYZ Card Withdrawals  \
# Transaction Date
# 2012-03-25               4                113                          26
# 2017-01-19               3                 30                          20
# 2013-05-30               0                103                          84
# 2011-12-22               1                 46                          28
# 2015-12-23               3                166                         116
#
#                   No Of Other Card Withdrawals  Amount withdrawn XYZ Card  \
# Transaction Date
# 2012-03-25                                  87                     120900
# 2017-01-19                                  10                      32800
# 2013-05-30                                  19                     368100
# 2011-12-22                                  18                     127200
# 2015-12-23                                  50                     734700
#
#                   Amount withdrawn Other Card  Weekday  Festival Religion  \
# Transaction Date
# 2012-03-25                             154200        6                  4
# 2017-01-19                              13700        3                  4
# 2013-05-30                              31400        3                  4
# 2011-12-22                              59600        3                  4
# 2015-12-23                             254200        2                  4
#
#                   Working Day  Holiday Sequence  Year  Month  Day  \
# Transaction Date
# 2012-03-25                  0                 1  2012      3   25
# 2017-01-19                  1                 7  2017      1   19
# 2013-05-30                  1                 7  2013      5   30
# 2011-12-22                  1                 7  2011     12   22
# 2015-12-23                  1                 7  2015     12   23
#
#                      Sin_Month     Cos_Month  Total amount Withdrawn  \
# Transaction Date
# 2012-03-25        1.000000e+00  6.123234e-17                  275100
# 2017-01-19        5.000000e-01  8.660254e-01                   46500
# 2013-05-30        5.000000e-01 -8.660254e-01                  399500
# 2011-12-22       -2.449294e-16  1.000000e+00                  186800
# 2015-12-23       -2.449294e-16  1.000000e+00                  988900
#
#                   Predicted_Value  Individual Error
# Transaction Date
# 2012-03-25            281179.8750         6079.8750
# 2017-01-19             84814.0625        38314.0625
# 2013-05-30            404190.0000         4690.0000
# 2011-12-22            195725.0625         8925.0625
# 2015-12-23            955349.5625       -33550.4375

# %%
original_train_df.to_csv("Train.csv", index=False)

# %% [markdown]
# # TEST DATA SET

# %%
y_test_pred = model.predict(X_test_reshape)
print(y_test_pred)
# Out:
# 37/37 [==============================] - 0s 2ms/step
# [[-0.77911496]
#  [ 1.864071  ]
#  [-0.24078551]
#  ...
#  [-0.5333168 ]
#  [ 0.55186105]
#  [ 0.52928174]]

# %%
# Calculate evaluation metrics
mse = mean_squared_error(y_test_scale, y_test_pred )
mae = mean_absolute_error(y_test_scale, y_test_pred )

print("Mean Squared Error (MSE) on training data:", mse)
print("Mean Absolute Error (MAE) on training data:", mae)
# Out:
# Mean Squared Error (MSE) on training data: 0.002046575600707695
# Mean Absolute Error (MAE) on training data: 0.0276668460642672

# %%
# Plot actual vs predicted values
plt.figure(figsize=(10, 6))
plt.scatter(y_test_scale, y_test_pred, color='blue')
plt.plot([min(y_test_scale), max(y_test_scale)], [min(y_test_scale), max(y_test_scale)], linestyle='--', color='red')
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Actual vs Predicted Values on Training Data")
plt.show()

# %%
import matplotlib.pyplot as plt

# Plot actual vs predicted values with time series format
plt.figure(figsize=(12, 6))
plt.plot(range(len(y_test_scale)), y_test_scale, label='Actual', color='blue')
plt.plot(range(len(y_test_pred)), y_test_pred, label='Predicted', color='red', linestyle='--')
plt.xlabel('Index')
plt.ylabel('Value')
plt.title('Actual vs Predicted Values')
plt.legend()
plt.show()

# %%
# Plot actual vs predicted values using a scatter plot
plt.figure(figsize=(12, 6))
plt.scatter(range(len(y_test_scale)), y_test_scale, label='Actual', color='blue', marker='.')
plt.scatter(range(len(y_test_pred)), y_test_pred, label='Predicted', color='red', marker='.')
plt.xlabel('Index')
plt.ylabel('Value')
plt.title('Actual vs Predicted Values')
plt.legend()
plt.show()

# %%
y_test_rescaled = std.inverse_transform(y_test_pred)


print(y_test_rescaled)
# Out:
# [[ 270780.38]
#  [1107502.2 ]
#  [ 441192.94]
#  ...
#  [ 348589.78]
#  [ 692111.6 ]
#  [ 684963.94]]

# %%
# Concatenate the two DataFrames side by side
original_test_df = pd.concat([X_test, y_test], axis=1)

# Display the concatenated DataFrame
original_test_df.head()
# Out:
#                   ATM Name  No Of Withdrawals  No Of XYZ Card Withdrawals  \
# Transaction Date
# 2013-05-03               1                 88                          31
# 2013-02-13               3                239                         181
# 2014-06-15               1                122                          39
# 2012-10-08               3                242                         187
# 2013-03-07               0                137                         103
#
#                   No Of Other Card Withdrawals  Amount withdrawn XYZ Card  \
# Transaction Date
# 2013-05-03                                  57                     125400
# 2013-02-13                                  58                     854800
# 2014-06-15                                  83                     197300
# 2012-10-08                                  55                     974800
# 2013-03-07                                  34                     681000
#
#                   Amount withdrawn Other Card  Weekday  Festival Religion  \
# Transaction Date
# 2013-05-03                             127700        4                  4
# 2013-02-13                             252400        2                  4
# 2014-06-15                             244400        6                  4
# 2012-10-08                             223500        0                  4
# 2013-03-07                             119000        3                  4
#
#                   Working Day  Holiday Sequence  Year  Month  Day  \
# Transaction Date
# 2013-05-03                  1                 7  2013      5    3
# 2013-02-13                  1                 7  2013      2   13
# 2014-06-15                  0                 1  2014      6   15
# 2012-10-08                  0                 1  2012     10    8
# 2013-03-07                  1                 7  2013      3    7
#
#                      Sin_Month     Cos_Month  Total amount Withdrawn
# Transaction Date
# 2013-05-03        5.000000e-01 -8.660254e-01                  253100
# 2013-02-13        8.660254e-01  5.000000e-01                 1107200
# 2014-06-15        1.224647e-16 -1.000000e+00                  441700
# 2012-10-08       -8.660254e-01  5.000000e-01                 1198300
# 2013-03-07        1.000000e+00  6.123234e-17                  800000

# %%
# Create a new column in the DataFrame for the predicted values
original_test_df['Predicted_Value'] = y_test_rescaled

# Display the DataFrame with the predicted values added
original_test_df.head()
# Out:
#                   ATM Name  No Of Withdrawals  No Of XYZ Card Withdrawals  \
# Transaction Date
# 2013-05-03               1                 88                          31
# 2013-02-13               3                239                         181
# 2014-06-15               1                122                          39
# 2012-10-08               3                242                         187
# 2013-03-07               0                137                         103
#
#                   No Of Other Card Withdrawals  Amount withdrawn XYZ Card  \
# Transaction Date
# 2013-05-03                                  57                     125400
# 2013-02-13                                  58                     854800
# 2014-06-15                                  83                     197300
# 2012-10-08                                  55                     974800
# 2013-03-07                                  34                     681000
#
#                   Amount withdrawn Other Card  Weekday  Festival Religion  \
# Transaction Date
# 2013-05-03                             127700        4                  4
# 2013-02-13                             252400        2                  4
# 2014-06-15                             244400        6                  4
# 2012-10-08                             223500        0                  4
# 2013-03-07                             119000        3                  4
#
#                   Working Day  Holiday Sequence  Year  Month  Day  \
# Transaction Date
# 2013-05-03                  1                 7  2013      5    3
# 2013-02-13                  1                 7  2013      2   13
# 2014-06-15                  0                 1  2014      6   15
# 2012-10-08                  0                 1  2012     10    8
# 2013-03-07                  1                 7  2013      3    7
#
#                      Sin_Month     Cos_Month  Total amount Withdrawn  \
# Transaction Date
# 2013-05-03        5.000000e-01 -8.660254e-01                  253100
# 2013-02-13        8.660254e-01  5.000000e-01                 1107200
# 2014-06-15        1.224647e-16 -1.000000e+00                  441700
# 2012-10-08       -8.660254e-01  5.000000e-01                 1198300
# 2013-03-07        1.000000e+00  6.123234e-17                  800000
#
#                   Predicted_Value
# Transaction Date
# 2013-05-03           2.707804e+05
# 2013-02-13           1.107502e+06
# 2014-06-15           4.411929e+05
# 2012-10-08           1.183766e+06
# 2013-03-07           7.910894e+05

# %%
# Calculate individual error
original_test_df['Individual Error'] =original_test_df['Predicted_Value'] - original_test_df['Total amount Withdrawn']

# Display the DataFrame with the individual error column added
original_test_df.head()
# Out:
#                   ATM Name  No Of Withdrawals  No Of XYZ Card Withdrawals  \
# Transaction Date
# 2013-05-03               1                 88                          31
# 2013-02-13               3                239                         181
# 2014-06-15               1                122                          39
# 2012-10-08               3                242                         187
# 2013-03-07               0                137                         103
#
#                   No Of Other Card Withdrawals  Amount withdrawn XYZ Card  \
# Transaction Date
# 2013-05-03                                  57                     125400
# 2013-02-13                                  58                     854800
# 2014-06-15                                  83                     197300
# 2012-10-08                                  55                     974800
# 2013-03-07                                  34                     681000
#
#                   Amount withdrawn Other Card  Weekday  Festival Religion  \
# Transaction Date
# 2013-05-03                             127700        4                  4
# 2013-02-13                             252400        2                  4
# 2014-06-15                             244400        6                  4
# 2012-10-08                             223500        0                  4
# 2013-03-07                             119000        3                  4
#
#                   Working Day  Holiday Sequence  Year  Month  Day  \
# Transaction Date
# 2013-05-03                  1                 7  2013      5    3
# 2013-02-13                  1                 7  2013      2   13
# 2014-06-15                  0                 1  2014      6   15
# 2012-10-08                  0                 1  2012     10    8
# 2013-03-07                  1                 7  2013      3    7
#
#                      Sin_Month     Cos_Month  Total amount Withdrawn  \
# Transaction Date
# 2013-05-03        5.000000e-01 -8.660254e-01                  253100
# 2013-02-13        8.660254e-01  5.000000e-01                 1107200
# 2014-06-15        1.224647e-16 -1.000000e+00                  441700
# 2012-10-08       -8.660254e-01  5.000000e-01                 1198300
# 2013-03-07        1.000000e+00  6.123234e-17                  800000
#
#                   Predicted_Value  Individual Error
# Transaction Date
# 2013-05-03           2.707804e+05        17680.3750
# 2013-02-13           1.107502e+06          302.2500
# 2014-06-15           4.411929e+05         -507.0625
# 2012-10-08           1.183766e+06       -14533.8750
# 2013-03-07           7.910894e+05        -8910.5625

# %%
original_test_df.to_csv("Test.csv", index=False)

# %% [markdown]
# # VALIDATION DATASET

# %%
y_val_pred = model.predict(X_val_reshape)
print(y_val_pred)
# Out:
# 33/33 [==============================] - 0s 2ms/step
# [[-0.74271625]
#  [-0.13375528]
#  [ 1.1029143 ]
#  ...
#  [-0.03593325]
#  [-0.02778142]
#  [ 0.8997636 ]]

# %%
# Calculate evaluation metrics
mse = mean_squared_error(y_val_scale, y_val_pred )
mae = mean_absolute_error(y_val_scale, y_val_pred )

print("Mean Squared Error (MSE) on training data:", mse)
print("Mean Absolute Error (MAE) on training data:", mae)
# Out:
# Mean Squared Error (MSE) on training data: 0.0017355223216805398
# Mean Absolute Error (MAE) on training data: 0.029980031366271986

# %%
y_val_rescaled = std.inverse_transform(y_val_pred)


print(y_test_rescaled)
# Out:
# [[ 270780.38]
#  [1107502.2 ]
#  [ 441192.94]
#  ...
#  [ 348589.78]
#  [ 692111.6 ]
#  [ 684963.94]]

# %%
# Concatenate the two DataFrames side by side
original_val_df = pd.concat([X_val, y_val], axis=1)

# Display the concatenated DataFrame
original_val_df.head()
# Out:
#                   ATM Name  No Of Withdrawals  No Of XYZ Card Withdrawals  \
# Transaction Date
# 2014-02-25               1                 94                          29
# 2015-10-18               4                178                          75
# 2015-07-05               2                178                          64
# 2012-06-16               4                179                          88
# 2014-06-29               0                 58                          45
#
#                   No Of Other Card Withdrawals  Amount withdrawn XYZ Card  \
# Transaction Date
# 2014-02-25                                  65                     122400
# 2015-10-18                                 103                     276200
# 2015-07-05                                 114                     353800
# 2012-06-16                                  91                     311900
# 2014-06-29                                  13                     201000
#
#                   Amount withdrawn Other Card  Weekday  Festival Religion  \
# Transaction Date
# 2014-02-25                             148900        1                  4
# 2015-10-18                             200600        6                  4
# 2015-07-05                             529300        6                  4
# 2012-06-16                             201600        5                  4
# 2014-06-29                              23100        6                  4
#
#                   Working Day  Holiday Sequence  Year  Month  Day  \
# Transaction Date
# 2014-02-25                  1                 7  2014      2   25
# 2015-10-18                  0                 1  2015     10   18
# 2015-07-05                  1                 7  2015      7    5
# 2012-06-16                  0                 1  2012      6   16
# 2014-06-29                  0                 1  2014      6   29
#
#                      Sin_Month  Cos_Month  Total amount Withdrawn
# Transaction Date
# 2014-02-25        8.660254e-01   0.500000                  271300
# 2015-10-18       -8.660254e-01   0.500000                  476800
# 2015-07-05       -5.000000e-01  -0.866025                  883100
# 2012-06-16        1.224647e-16  -1.000000                  513500
# 2014-06-29        1.224647e-16  -1.000000                  224100

# %%
# Create a new column in the DataFrame for the predicted values
original_val_df['Predicted_Value'] = y_val_rescaled

# Display the DataFrame with the predicted values added
original_val_df.head()
# Out:
#                   ATM Name  No Of Withdrawals  No Of XYZ Card Withdrawals  \
# Transaction Date
# 2014-02-25               1                 94                          29
# 2015-10-18               4                178                          75
# 2015-07-05               2                178                          64
# 2012-06-16               4                179                          88
# 2014-06-29               0                 58                          45
#
#                   No Of Other Card Withdrawals  Amount withdrawn XYZ Card  \
# Transaction Date
# 2014-02-25                                  65                     122400
# 2015-10-18                                 103                     276200
# 2015-07-05                                 114                     353800
# 2012-06-16                                  91                     311900
# 2014-06-29                                  13                     201000
#
#                   Amount withdrawn Other Card  Weekday  Festival Religion  \
# Transaction Date
# 2014-02-25                             148900        1                  4
# 2015-10-18                             200600        6                  4
# 2015-07-05                             529300        6                  4
# 2012-06-16                             201600        5                  4
# 2014-06-29                              23100        6                  4
#
#                   Working Day  Holiday Sequence  Year  Month  Day  \
# Transaction Date
# 2014-02-25                  1                 7  2014      2   25
# 2015-10-18                  0                 1  2015     10   18
# 2015-07-05                  1                 7  2015      7    5
# 2012-06-16                  0                 1  2012      6   16
# 2014-06-29                  0                 1  2014      6   29
#
#                      Sin_Month  Cos_Month  Total amount Withdrawn  \
# Transaction Date
# 2014-02-25        8.660254e-01   0.500000                  271300
# 2015-10-18       -8.660254e-01   0.500000                  476800
# 2015-07-05       -5.000000e-01  -0.866025                  883100
# 2012-06-16        1.224647e-16  -1.000000                  513500
# 2014-06-29        1.224647e-16  -1.000000                  224100
#
#                   Predicted_Value
# Transaction Date
# 2014-02-25           282302.68750
# 2015-10-18           475074.21875
# 2015-07-05           866551.93750
# 2012-06-16           509861.93750
# 2014-06-29           232566.43750

# %%
# Calculate individual error
original_val_df['Individual Error'] =original_val_df['Predicted_Value'] - original_val_df['Total amount Withdrawn']

# Display the DataFrame with the individual error column added
original_val_df.head()
# Out:
#                   ATM Name  No Of Withdrawals  No Of XYZ Card Withdrawals  \
# Transaction Date
# 2014-02-25               1                 94                          29
# 2015-10-18               4                178                          75
# 2015-07-05               2                178                          64
# 2012-06-16               4                179                          88
# 2014-06-29               0                 58                          45
#
#                   No Of Other Card Withdrawals  Amount withdrawn XYZ Card  \
# Transaction Date
# 2014-02-25                                  65                     122400
# 2015-10-18                                 103                     276200
# 2015-07-05                                 114                     353800
# 2012-06-16                                  91                     311900
# 2014-06-29                                  13                     201000
#
#                   Amount withdrawn Other Card  Weekday  Festival Religion  \
# Transaction Date
# 2014-02-25                             148900        1                  4
# 2015-10-18                             200600        6                  4
# 2015-07-05                             529300        6                  4
# 2012-06-16                             201600        5                  4
# 2014-06-29                              23100        6                  4
#
#                   Working Day  Holiday Sequence  Year  Month  Day  \
# Transaction Date
# 2014-02-25                  1                 7  2014      2   25
# 2015-10-18                  0                 1  2015     10   18
# 2015-07-05                  1                 7  2015      7    5
# 2012-06-16                  0                 1  2012      6   16
# 2014-06-29                  0                 1  2014      6   29
#
#                      Sin_Month  Cos_Month  Total amount Withdrawn  \
# Transaction Date
# 2014-02-25        8.660254e-01   0.500000                  271300
# 2015-10-18       -8.660254e-01   0.500000                  476800
# 2015-07-05       -5.000000e-01  -0.866025                  883100
# 2012-06-16        1.224647e-16  -1.000000                  513500
# 2014-06-29        1.224647e-16  -1.000000                  224100
#
#                   Predicted_Value  Individual Error
# Transaction Date
# 2014-02-25           282302.68750       11002.68750
# 2015-10-18           475074.21875       -1725.78125
# 2015-07-05           866551.93750      -16548.06250
# 2012-06-16           509861.93750       -3638.06250
# 2014-06-29           232566.43750        8466.43750

# %%
original_val_df.to_csv("Val.csv", index=False)
